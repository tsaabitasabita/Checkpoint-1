# %% [markdown]
# <a href="https://colab.research.google.com/github/tsaabitasabita/Checkpoint-1/blob/main/Check_point2_2409116099_Tsabitah_Kawiswara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Tsabitah Kawiswara
#
# Nim     : 2409116099

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## Menampilkan data kunjungan website beserta sumber data

# %%
 import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/daily-website-visitors.csv')

# %%
print("Sumber Data: https://www.kaggle.com/datasets/bobnau/daily-website-visitors")
df.info()
# Out:
# Sumber Data: https://www.kaggle.com/datasets/bobnau/daily-website-visitors
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row                2167 non-null   int64
#  1   Day                2167 non-null   object
#  2   Day.Of.Week        2167 non-null   int64
#  3   Date               2167 non-null   object
#  4   Page.Loads         2167 non-null   object
#  5   Unique.Visits      2167 non-null   object
#  6   First.Time.Visits  2167 non-null   object
#  7   Returning.Visits   2167 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 135.6+ KB

# %%
print (df)
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %% [markdown]
# ## Pengecekan strutur data

# %% [markdown]
# >Menghitung jumlah kemunculan nilai unik dalam kolom 'Day'.

# %%
kolom_tertentu = "Day"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}':")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'Day':
# Day
# Sunday       310
# Monday       310
# Tuesday      310
# Wednesday    310
# Thursday     309
# Friday       309
# Saturday     309
# Name: count, dtype: int64

# %% [markdown]
# >Menghitung rata-rata jumlah kunjungan harian untuk mengetahui tingkat kunjungan keseluruhan.

# %%
print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))
# Out:
# Menghitung rata-rata dengan df.mean():
# Row            1084.000000
# Day.Of.Week       3.997231
# dtype: float64

# %% [markdown]
# >Menghitung median jumlah kunjungan untuk mengetahui nilai tengah distribusi kunjungan.

# %%
print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))
# Out:
# Menghitung median dengan df.median():
# Row            1084.0
# Day.Of.Week       4.0
# dtype: float64

# %%
Menghitung standar deviasi untuk mengetahui variasi kunjungan dari hari ke hari.

# %%
print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))
# Out:
# Menghitung standar deviasi dengan df.std():
# Row            625.703338
# Day.Of.Week      2.000229
# dtype: float64

# %% [markdown]
# >Menghitung kolerasi

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#                 Row  Day.Of.Week
# Row          1.0000       0.0008
# Day.Of.Week  0.0008       1.0000

# %% [markdown]
# ## Jumlah baris dan kolom dataset

# %%
print("\nMenampilkan jumlah baris dan kolom dengan df.shape:")
print(df.shape)
# Out:
# Menampilkan jumlah baris dan kolom dengan df.shape:
# (2167, 8)

# %% [markdown]
# ## Tipe data setiap kolom

# %%
print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
print(df.dtypes)
# Out:
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# Row                   int64
# Day                  object
# Day.Of.Week           int64
# Date                 object
# Page.Loads           object
# Unique.Visits        object
# First.Time.Visits    object
# Returning.Visits     object
# dtype: object

# %% [markdown]
# ## Statistik deksriptif

# %%
df.describe()
# Out:
#                Row  Day.Of.Week
# count  2167.000000  2167.000000
# mean   1084.000000     3.997231
# std     625.703338     2.000229
# min       1.000000     1.000000
# 25%     542.500000     2.000000
# 50%    1084.000000     4.000000
# 75%    1625.500000     6.000000
# max    2167.000000     7.000000

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# Menampilkan data beserta sumber data

# %%
print("Sumber Data: https://www.kaggle.com/datasets/bobnau/daily-website-visitors")
df
# Out:
# Sumber Data: https://www.kaggle.com/datasets/bobnau/daily-website-visitors
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# ...

# %% [markdown]
# ## Melakukan pengecekan missing values

# %% [markdown]
# Pada dataset tidak ada data yang hilang atau data yang tidak terbaca yang bisa dilihat dari hasil pengecekan missing values (0,0) untuk seluruh kolom, sehingga tidak dilakukan penanganan seperti menghapus atau amputasi data.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Row                  0.0
# Day                  0.0
# Day.Of.Week          0.0
# Date                 0.0
# Page.Loads           0.0
# Unique.Visits        0.0
# First.Time.Visits    0.0
# Returning.Visits     0.0
# dtype: float64

# %% [markdown]
# ## Melakukan pengecekan outliers

# %% [markdown]
# Pada dataset tidak terdapat nilai yang berbeda jauh lebih rendah atau lebih tinggi, maka bisa dikatakan dataset ini memiliki nilai yang konsistes sehinggan tidak dilakukan penanganan pada pengecekan outliers.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# %%
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# %%
display(results_df)
# Out:
# Kolom        Persentase Outliers
# Row                          0.0
# Day.Of.Week                  0.0

# %%
df
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %% [markdown]
# ## Melakukan pengecekan duplicated values

# %% [markdown]
# Pada dataset tidak terdapat data yang sama muncul beberapa kali, sehingga tidak ada penghapusan atau penanganan untuk duplicated values.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row, Day, Day.Of.Week, Date, Page.Loads, Unique.Visits, First.Time.Visits, Returning.Visits]
# Index: []

# %% [markdown]
# ## Melakukan pengecekan inconsistent values

# %% [markdown]
# Pada dataset tidak terdapat nilai-nilai yan tidak sesuai format atau memiliki tipe data yang berbeda sehingga tidak ada dilakukan penanganan pada dataset.

# %%
df
# Out:
#        Row        Day  Day.Of.Week        Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  14-09-2014      2,146         1,582
# 1        2     Monday            2  15-09-2014      3,621         2,528
# 2        3    Tuesday            3  16-09-2014      3,698         2,630
# 3        4  Wednesday            4  17-09-2014      3,667         2,614
# 4        5   Thursday            5  18-09-2014      3,316         2,366
# ...    ...        ...          ...         ...        ...           ...
# 2162  2163   Saturday            7  15-08-2020      2,221         1,696
# 2163  2164     Sunday            1  16-08-2020      2,724         2,037
# 2164  2165     Monday            2  17-08-2020      3,456         2,638
# 2165  2166    Tuesday            3  18-08-2020      3,581         2,683
# 2166  2167  Wednesday            4  19-08-2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %% [markdown]
# ## Melakukan data reduction

# %% [markdown]
# Kolom "Row" hanya berisi nomor urut yang tidak diperlukan dalam analisis, sedangkan "Day.Of.Week" hanya menunjukan urutan angka dalam seminggu , sehingga kedua kolom tersebut dihapus agar dapat dianalisis dengan mudah dengan informasi yang dibutuhkan.

# %%
df
# Out:
#             Day       Date Page.Loads Unique.Visits First.Time.Visits  \
# 0        Sunday 2014-09-14      2,146         1,582             1,430
# 1        Monday 2014-09-15      3,621         2,528             2,297
# 2       Tuesday 2014-09-16      3,698         2,630             2,352
# 3     Wednesday 2014-09-17      3,667         2,614             2,327
# 4      Thursday 2014-09-18      3,316         2,366             2,130
# ...         ...        ...        ...           ...               ...
# 2162   Saturday 2020-08-15      2,221         1,696             1,373
# 2163     Sunday 2020-08-16      2,724         2,037             1,686
# 2164     Monday 2020-08-17      3,456         2,638             2,181
# 2165    Tuesday 2020-08-18      3,581         2,683             2,184
# 2166  Wednesday 2020-08-19      2,064         1,564             1,297
#
#      Returning.Visits  Year   Day_Name  Month
# 0                 152  2014     Sunday      9
# ...

# %% [markdown]
# ## Construct data

# %% [markdown]
# Dataset sudah memiliki informasi yang cukup untuk analisis, seperti tanggal, jumlah kunjungan unik, pengunjung baru, dan pengunjung kembali. Tidak ada kebutuhan untuk menambahkan kolom baru karena semua informasi yang diperlukan sudah tersedia.
